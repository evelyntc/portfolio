# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import seaborn as sns
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import RegexpTokenizer
import re
import string
import random
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("gr_books.csv")
df
# Out:
#       Unnamed: 0                                               Desc  \
# 0              0  We know that power is shifting: From West to E...
# 1              1  Following the success of The Accidental Billio...
# 2              2  How to tap the power of social software and ne...
# 3              3  William J. Bernstein is an American financial ...
# 4              4  Amazing book. And I joined Steve Jobs and many...
# ...          ...                                                ...
# 2377        2446  Ralph Roberts, a sus setenta años y tras la mu...
# 2378        2447  Murder at the Vicarage marks the debut of Agat...
# 2379        2448  In 1951 John Wyndham published his novel The D...
# 2380        2449  This now classic book revealed Flannery O'Conn...
# 2381        2450  Imbued on every page with Frank McCourt's asto...
#
#       Unnamed: 0.1                author        genre  \
# 0              0.0           Moisés Naím     Business
# ...

# %% [markdown]
# ## Cleaning

# %%
df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                 Desc                author  \
# 0  We know that power is shifting: From West to E...           Moisés Naím
# 1  Following the success of The Accidental Billio...       Blake J. Harris
# 2  How to tap the power of social software and ne...          Chris Brogan
# 3  William J. Bernstein is an American financial ...  William J. Bernstein
# 4  Amazing book. And I joined Steve Jobs and many...           Akio Morita
#
#       genre                                         image_link  rating  \
# 0  Business  https://i.gr-assets.com/images/S/compressed.ph...    3.63
# 1  Business  https://i.gr-assets.com/images/S/compressed.ph...    3.94
# 2  Business  https://i.gr-assets.com/images/S/compressed.ph...    3.78
# 3  Business  https://i.gr-assets.com/images/S/compressed.ph...    4.20
# 4  Business  https://i.gr-assets.com/images/S/compressed.ph...    4.05
#
#                                                title
# ...

# %%
df
# Out:
#                                                    Desc                author  \
# 0     We know that power is shifting: From West to E...           Moisés Naím
# 1     Following the success of The Accidental Billio...       Blake J. Harris
# 2     How to tap the power of social software and ne...          Chris Brogan
# 3     William J. Bernstein is an American financial ...  William J. Bernstein
# 4     Amazing book. And I joined Steve Jobs and many...           Akio Morita
# ...                                                 ...                   ...
# 2377  Ralph Roberts, a sus setenta años y tras la mu...          Stephen King
# 2378  Murder at the Vicarage marks the debut of Agat...       Agatha Christie
# 2379  In 1951 John Wyndham published his novel The D...          John Wyndham
# 2380  This now classic book revealed Flannery O'Conn...     Flannery O'Connor
# 2381  Imbued on every page with Frank McCourt's asto...         Frank McCourt
#
# ...

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(10,8))
plt.title('Genre Distribution')
sns.set(style = 'darkgrid')
ax = sns.countplot(x = 'genre', data = df)

# %%
books = df['title'].value_counts()[:25]
rating = df.rating[:25]
print(books)
# Out:
# The Fountainhead                                                                                                                   2
# The Startup Way: Making Entrepreneurship a Fundamental Discipline of Every Enterprise                                              2
# Inferno                                                                                                                            2
# Atlas Shrugged                                                                                                                     2
# The Connected Company                                                                                                              1
# Dare to Lead                                                                                                                       1
# The Eyre Affair                                                                                                                    1
# ...

# %%
books = df['title'].value_counts()[:20]
                                   
rating = df.rating[:20]

plt.figure(figsize=(10,8))
           
bar = sns.barplot(x = rating, y = books.index)

bar.set_xticklabels(bar.get_xticklabels(), rotation=30)

plt.title('Top 20 Most Popular Business & Non-Fiction Books on Goodreads')
plt.xlabel('Amount')
plt.ylabel('Book')
plt.show()
# Out:
# C:\Users\etc\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   if __name__ == '__main__':

# %% [markdown]
# ## Preprocessing and Modeling

# %%
#this code was sourced by: https://towardsdatascience.com/building-a-content-based-book-recommendation-engine-9fd4d57a4da

def recommend(title, genre):
    
    # Matching the genre with the dataset and reset the index
    data = df.loc[df['genre'] == genre]  
    data.reset_index(level = 0, inplace = True) 
  
    # Convert the index into series
    indices = pd.Series(data.index, index = data['title'])
    
    #Converting the book title into vectors and used bigram
    tf = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), min_df = 1, stop_words='english')
    tfidf_matrix = tf.fit_transform(data['title'])
    
    # Calculating the similarity measures based on Cosine Similarity
    sg = cosine_similarity(tfidf_matrix, tfidf_matrix)
    
    # Get the index corresponding to original_title
       
    idx = indices[title]
# Get the pairwsie similarity scores 
    sig = list(enumerate(sg[idx]))
# Sort the books
    sig = sorted(sig, key=lambda x: x[1], reverse=True)
# Scores of the 5 most similar books 
    sig = sig[1:6]
# Book indicies
    movie_indices = [i[0] for i in sig]
   
    # Top 5 book recommendation
    rec = data[['title', 'image_link']].iloc[movie_indices]
       
    # It reads the top 5 recommend book url and print the images
    
    for i in rec['image_link']:
        response = requests.get(i)
        img = Image.open(BytesIO(response.content))
        plt.figure()
        print(plt.imshow(img))

# %%
recommend('Steve Jobs', "Business")
# Out:
# C:\Users\etc\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
recommend('When to Rob a Bank', 'Business')
# Out:
# C:\Users\etc\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
recommend('Life of Pi', 'Non-Fiction')
# Out:
# C:\Users\etc\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
recommend('The Starless Sea', 'Non-Fiction')
# Out:
# C:\Users\etc\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
recommend('A Gentleman in Moscow', 'Non-Fiction')
# Out:
# C:\Users\etc\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
recommend('Insomnia', 'Non-Fiction')
# Out:
# C:\Users\etc\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
# source:
# https://towardsdatascience.com/building-a-content-based-book-recommendation-engine-9fd4d57a4da
